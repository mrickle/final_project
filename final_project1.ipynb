# %%
#Import dependencies

from sqlalchemy import create_engine
import pandas as pd
import os
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
#Create password variable
#from config import
db_password = 'Hetheru7!'

# %%
#Create connection string
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/NFL Predict"

# %%
#Create the database engine
engine = create_engine(db_string)

# %%
#Import SQL tables as dataframes


standings_df = pd.read_sql_table('standings',db_string)
sales_df =  pd.read_sql_table('team_sales',db_string)
ratings_df = pd.read_sql_table('team_ratings',db_string)
teams_df = pd.read_sql_table('teams',db_string)

# %%
standings_df
# Out:
#    team_id wins_2021 losses_2021 win_pct_2021 wins_2020 losses_2020  \
# 0   NFC001        11           6        0.647         8           8
# 1   NFC002         7          10        0.412         4          12
# 2   NFC003         5          12        0.294         5          11
# 3   NFC004         6          11        0.353         8           8
# 4   NFC005        12           5        0.706         6          10
# 5   NFC006         3          13        0.206         5          11
# 6   NFC007        13           4        0.765        13           3
# 7   NFC008        12           5        0.706        10           6
# 8   NFC009         8           9        0.471         7           9
# 9   NFC010         9           8        0.529        12           4
# 10  NFC011         4          13        0.235         6          10
# 11  NFC012         9           8        0.529         4          11
# 12  NFC013        10           7        0.588         6          10
# ...

# %%
#Create ticket sales dataframe
sales_df
# Out:
#    team_id pct_2021 pct_2020 pct_2019
# 0   AFC001     99.7     11.6     96.8
# 1   AFC002     94.7        9     95.6
# 2   AFC003     92.1     14.6     84.9
# 3   AFC004      100     15.2     97.5
# 4   AFC005    100.1      6.3     98.3
# 5   AFC006     92.8     17.6     98.8
# 6   AFC007     99.2     15.5     94.3
# 7   AFC008     89.2       21     92.8
# 8   AFC009    100.4     14.8    101.5
# 9   AFC010     94.1      9.6     96.1
# 10  AFC016    100.1     21.6     94.7
# 11  AFC011     99.4     15.6     95.2
# 12  AFC012      100      9.3     98.2
# 13  AFC013     86.9      8.5     91.6
# 14  AFC014     88.4     14.2     93.1
# 15  AFC015     99.2       18     94.9
# 16  NFC001     96.3     10.5     91.7
# 17  NFC002     90.1     12.8     95.8
# 18  NFC003     97.5      7.4     97.3
# 19  NFC004     98.9     13.4     98.2
# 20  NFC005     93.4     27.1     93.3
# 21  NFC006     79.9     15.3     94.2
# 22  NFC007     95.8     20.3     96.3
# 23  NFC008     98.2        9    101.1
# ...

# %%
# Import joined table from SQL DB
ratings_df = pd.read_sql_table('team_ratings',db_string)
ratings_df
# Out:
#    team_id qbr_2021 qbr_2020 qbr_2019 off_ranking_2021 off_ranking_2020  \
# 0   NFC001    100.6     94.1       87                8                6
# 1   NFC002     90.4     93.9     93.8               29               18
# 2   AFC001     84.4     95.7      109                6               19
# 3   AFC002     91.3    107.6     82.9                5                2
# 4   NFC003     68.2     87.5     74.7               30               21
# 5   NFC004     73.2     86.5     83.9               24               26
# 6   AFC003    106.9     85.7     76.2               13               29
# 7   AFC004     84.6     96.6     78.4               18               16
# 8   NFC005    104.2     89.9     99.5                1               14
# 9   AFC005     91.7     72.5     84.1               19               23
# 10  NFC006     91.5     93.3     88.2               22               20
# 11  NFC007    111.9    121.5     95.3               10                5
# ...

# %%
teams_df
# Out:
#                team_name  div team_id
# 0                Arizona  NFC  NFC001
# 1                Atlanta  NFC  NFC002
# 2              Baltimore  AFC  AFC001
# 3                Buffalo  AFC  AFC002
# 4               Carolina  NFC  NFC003
# 5                Chicago  NFC  NFC004
# 6             Cincinnati  AFC  AFC003
# 7              Cleveland  AFC  AFC004
# 8                 Dallas  NFC  NFC005
# 9                 Denver  AFC  AFC005
# 10               Detroit  NFC  NFC006
# 11             Green Bay  NFC  NFC007
# 12               Houston  AFC  AFC006
# 13          Indianapolis  AFC  AFC007
# 14          Jacksonville  AFC  AFC008
# 15           Kansas City  AFC  AFC009
# 16             Las Vegas  AFC  AFC010
# 17  Los Angeles Chargers  AFC  AFC016
# 18     Los Angeles Rams   NFC  NFC008
# 19                 Miami  AFC  AFC011
# 20             Minnesota  NFC  NFC009
# 21           New England  AFC  AFC012
# 22           New Orleans  NFC  NFC010
# 23             NY Giants  NFC  NFC011
# ...

# %%
NFC_DF = pd.merge(standings_df,ratings_df, on=["team_id"])
NFC_DF = pd.merge(teams_df,NFC_DF, on=["team_id","team_id"])

NFC_DF
# Out:
#                team_name  div team_id wins_2021 losses_2021 win_pct_2021  \
# 0                Arizona  NFC  NFC001        11           6        0.647
# 1                Atlanta  NFC  NFC002         7          10        0.412
# 2              Baltimore  AFC  AFC001         8           9        0.471
# 3                Buffalo  AFC  AFC002        11           6        0.647
# 4               Carolina  NFC  NFC003         5          12        0.294
# 5                Chicago  NFC  NFC004         6          11        0.353
# 6             Cincinnati  AFC  AFC003        10           7        0.588
# 7              Cleveland  AFC  AFC004         8           9        0.471
# 8                 Dallas  NFC  NFC005        12           5        0.706
# 9                 Denver  AFC  AFC005         7          10        0.412
# 10               Detroit  NFC  NFC006         3          13        0.206
# 11             Green Bay  NFC  NFC007        13           4        0.765
# ...

# %%
# Create our features
X_drop = NFC_DF.drop(columns="wins")


# Create our target
y = NFC_DF["wins"]

#model = LinearRegression()
#model.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21508\1864527877.py in <module>
#       1 # Create our features
# ----> 2 X_drop = NFC_DF.drop(columns="wins")
#       3
#       4
#       5 # Create our target
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
# Out:
# 3      6
# 13     7
# 7     12
# 2      5
# Name: wins, dtype: int64

# %%
y_pred = model.predict(X)
print(y_pred.shape)
